# %%
import requests
import pandas as pd
from requests_html import HTML
from requests_html import HTMLSession

# %%
# !pip install requests-html

# %%
def get_source(url):
    """Return the source code for the provided URL. 

    Args: 
        url (string): URL of the page to scrape.

    Returns:
        response (object): HTTP response object from requests_html. 
    """

    try:
        session = HTMLSession()
        response = session.get(url)
        return response

    except requests.exceptions.RequestException as e:
        print(e)

# %%
def get_feed(url):
    """Return a Pandas dataframe containing the RSS feed contents.

    Args: 
        url (string): URL of the RSS feed to read.

    Returns:
        df (dataframe): Pandas dataframe containing the RSS feed contents.
    """
    
    response = get_source(url)
    
    df = pd.DataFrame(columns = ['title', 'pubDate', 'guid', 'description'])

    with response as r:
        items = r.html.find("item", first=False)

        for item in items:        

            title = item.find('title', first=True).text
            pubDate = item.find('pubDate', first=True).text
            guid = item.find('guid', first=True).text
            description = item.find('description', first=True).text

            row = {'title': title, 'pubDate': pubDate, 'guid': guid, 'description': description}
            df = df.append(row, ignore_index=True)

    return df

# %%
url = 'https://cdn.marschannels.com/files/feed/omjwr7pvui.xml'

# %%
df = get_feed(url)

# %%
df.head()
# Out:
#                           title                   pubDate      guid  \
# 0   Beyond The Usual - Quintana  2022-06-06T01:07:05.000Z  27069063
# 1      The Harriet Tubman Story  2022-06-05T00:31:22.000Z  27069064
# 2                   Benevolence  2022-06-02T13:48:51.000Z  27069065
# 3  Daddy We're Back - Episode 4  2022-06-06T12:21:54.000Z  27069066
# 4            Hercules Unchained  2022-06-03T22:54:38.000Z  27069067
#
#                                          description
# 0                        Beyond The Usual - Quintana
# 1  Does God answer prayers? Every day Harriet Tub...
# 2  Ruth, a young woman is tenacious to hold on to...
# 3                       Daddy We're Back - Episode 4
# 4  The Greek muscleman fights leopards, a giant a...

# %%
len(df)
# Out:
# 1304

# %%
df.to_csv('/content/drive/MyDrive/castify/search_feed.csv')

# %% [markdown]
# Merging the two data

# %%
import pandas as pd

# the search feed and duration

search_feed = '/content/drive/MyDrive/castify/search_feed.csv'

duration = '/content/drive/MyDrive/castify/duration.csv'

# read the data

search_feed = pd.read_csv(search_feed)

duration = pd.read_csv(duration)

search_feed = search_feed.drop('Unnamed: 0',axis=1)

# %%
search_feed['id'] = search_feed.index + 1

duration['id'] = duration.index + 1

search_feeds = pd.merge(search_feed, duration, on="id")

search_feeds = search_feeds.drop(['pubDate','id'],axis=1)

search_feeds.columns = ['title','video_id','description','duration(secs)']

search_feeds.to_excel('/content/drive/MyDrive/castify/search_feed_duration.xlsx',index=False)

# %%
search_feeds = pd.read_excel('/content/drive/MyDrive/castify/search_feed_duration.xlsx')

search_feeds.head()
# Out:
#                           title  video_id  \
# 0   Beyond The Usual - Quintana  27069063
# 1      The Harriet Tubman Story  27069064
# 2                   Benevolence  27069065
# 3  Daddy We're Back - Episode 4  27069066
# 4            Hercules Unchained  27069067
#
#                                          description  duration(secs)
# 0                        Beyond The Usual - Quintana             725
# 1  Does God answer prayers? Every day Harriet Tub...            1810
# 2  Ruth, a young woman is tenacious to hold on to...            7030
# 3                       Daddy We're Back - Episode 4            1326
# 4  The Greek muscleman fights leopards, a giant a...            5383

# %% [markdown]
# ### Extra analysis

# %%
search_feed['id'] = search_feed.index + 1

# search_feed = search_feed.set_index('id')

search_feed.head(2)
# Out:
#                          title                   pubDate      guid  \
# 0  Beyond The Usual - Quintana  2022-06-06T01:07:05.000Z  27069063
# 1     The Harriet Tubman Story  2022-06-05T00:31:22.000Z  27069064
#
#                                          description  id
# 0                        Beyond The Usual - Quintana   1
# 1  Does God answer prayers? Every day Harriet Tub...   2

# %%
duration['id'] = duration.index + 1

# duration = duration.set_index('id')

duration.head(2)
# Out:
#    duration  id
# 0       725   1
# 1      1810   2

# %%
search_feeds = pd.merge(search_feed, duration, on="id")

search_feeds

# %%
search_feeds = pd.read_excel('/content/drive/MyDrive/castify/search_feed_duration.xlsx')

search_feeds.head()
# Out:
#    Unnamed: 0                         title      guid  \
# 0           0   Beyond The Usual - Quintana  27069063
# 1           1      The Harriet Tubman Story  27069064
# 2           2                   Benevolence  27069065
# 3           3  Daddy We're Back - Episode 4  27069066
# 4           4            Hercules Unchained  27069067
#
#                                          description  duration
# 0                        Beyond The Usual - Quintana       725
# 1  Does God answer prayers? Every day Harriet Tub...      1810
# 2  Ruth, a young woman is tenacious to hold on to...      7030
# 3                       Daddy We're Back - Episode 4      1326
# 4  The Greek muscleman fights leopards, a giant a...      5383

# %%
search_feeds.columns = ['id', 'title', 'guid', 'description', 'duration(secs)']

# %%
search_feeds
# Out:
#         id                               title      guid  \
# 0        0         Beyond The Usual - Quintana  27069063
# 1        1            The Harriet Tubman Story  27069064
# 2        2                         Benevolence  27069065
# 3        3        Daddy We're Back - Episode 4  27069066
# 4        4                  Hercules Unchained  27069067
# ...    ...                                 ...       ...
# 1299  1299  Ponysitter's Club: Fun at the Fair  40018568
# 1300  1300        Christmas Recipe for Romance  40018586
# 1301  1301            Operation Christmas List  40035213
# 1302  1302                     Christmas Catch  40035600
# 1303  1303          Time Out Sports Show Ep 01  40895595
#
#                                             description  duration(secs)
# 0                           Beyond The Usual - Quintana             725
# 1     Does God answer prayers? Every day Harriet Tub...            1810
# 2     Ruth, a young woman is tenacious to hold on to...            7030
# 3                          Daddy We're Back - Episode 4            1326
# 4     The Greek muscleman fights leopards, a giant a...            5383
# ...                                                 ...             ...
# 1299  Excited about the Fall Fair, the Ponysitters a...            4811
# 1300  The owner of a historic inn decides to enter a...            5293
# 1301  12-year-old Barney has a plan to buy the entir...            5299
# 1302  Detective Bennett is on the trail of a thief a...            5204
# 1303                          Ep 01 - November 22, 2022            3358
#
# [1304 rows x 5 columns]

# %%
search_feeds.tail()
# Out:
#         id                               title      guid  \
# 1299  1299  Ponysitter's Club: Fun at the Fair  40018568
# 1300  1300        Christmas Recipe for Romance  40018586
# 1301  1301            Operation Christmas List  40035213
# 1302  1302                     Christmas Catch  40035600
# 1303  1303          Time Out Sports Show Ep 01  40895595
#
#                                             description  duration(secs)
# 1299  Excited about the Fall Fair, the Ponysitters a...            4811
# 1300  The owner of a historic inn decides to enter a...            5293
# 1301  12-year-old Barney has a plan to buy the entir...            5299
# 1302  Detective Bennett is on the trail of a thief a...            5204
# 1303                          Ep 01 - November 22, 2022            3358

# %%
search_feeds.to_excel('/content/drive/MyDrive/castify/search_feed_duration.xlsx')
